# %%
# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

from glob import glob
import functools
import os

import numpy as np
import pandas as pd

from pandas_linker import get_linker, run_linker

pd.options.display.max_rows = 999

from eurosfordoctors import utils
from eurosfordoctors import fixers
from eurosfordoctors import checks
from eurosfordoctors import dedupe
from eurosfordoctors import geocode
from eurosfordoctors import export

utils.progress_pandas_df()

# %%
os.makedirs('data/cleaned', exist_ok=True)

# %%
DEFAULT_COUNTRY = 'PL'
DEFAULT_YEAR = 2015

def parse_address_location_country_comma(s):
    s = s.rsplit(',', 2)
    return {
        'country': (' '.join(s[2:])).strip(),
        'location': s[1].strip(),
        'address': s[0].strip()
    }

ADDRESS_PARSERS = {
    ('abbvie',): parse_address_location_country_comma,
}

def flatten_parsers(d):
    for tup, func in d.items():
        for t in tup:
            yield (t, func)

COMPANY_SETTINGS = {
    'bad_name_order': [],
    'comma_split_title': [],
    'comma_split_title_name': [],
    'semicolon_name_split': [],
    'last_name_capitals': [],
    'no_postcode': ['abbvie', 'bayer'],
    'proper_postcode': [],
    'no_pdf': ['bayer'],
    'hcp_company_in_address': [],
    'address_rules': dict(flatten_parsers(ADDRESS_PARSERS))
}

def load_dataframe(filename, force_clean=False):
    print(filename)
    basename = os.path.basename(filename)
    basename = basename.split('.')[0]
    company = basename.split('_')[0]
    df = pd.read_csv(filename, encoding='utf-8', escapechar='\\', converters={'postcode': str, 'uci': str},
                     na_values=['-'])

    # Drop everything with empty name -> useless
    if df['name'].isnull().sum() != 0:
        print('%d null names!' % df['name'].isnull().sum())
    df = df[df['name'].notnull()]

    df['type'] = df['type'].str.lower()
    assert ((df['type'] == 'hcp').sum() + (df['type'] == 'hco').sum()) == len(df)

    # TODO: fix country
    df['recipient_detail'] = None
    df['base_country'] = DEFAULT_COUNTRY
    df['origin'] = DEFAULT_COUNTRY
    df['year'] = DEFAULT_YEAR
    df['company'] = company
    df = fixers.make_money(df)
    df = df.apply(lambda x: fixers.fix_name(x, COMPANY_SETTINGS), 1)
    df = df.apply(lambda x: fixers.split_name(x, COMPANY_SETTINGS), 1)
    df = df.apply(lambda x: fixers.fix_address(x, COMPANY_SETTINGS), 1)
    df['country'] = df['country'].apply(lambda x: fixers.fix_country(x, default=DEFAULT_COUNTRY))
    if 'postcode' in df:
        df['postcode'] = df['postcode'].apply(lambda x: np.nan if pd.notnull(x) and not x else x)
    else:
        df['postcode'] = np.nan

    df['uid'] = None
        
    if not 'gender' in df:
        df['gender'] = np.nan
    
    clean_name = './data/cleaned/%s_cleaned.csv' % basename
    df.to_csv(clean_name, index=False, encoding='utf-8')
    return df

# %%
df = pd.concat([load_dataframe(filename) for filename in glob('data/pl/raw_csv/*.csv')]).reset_index()
df.head()
# Out:
# data/pl/raw_csv/abbvie_pl_2015.csv
# data/pl/raw_csv/bayer_pl_2015.csv
#    index                 address base_country                     clean_name  \
# 0      0  al.Wojska Polskiego 30           PL            tomasz-aleksiejczyk
# 1      1      ul.Szpitalna 27/33           PL  alicja-bartkowska-sniatkowska
# 2      2          ul.Roentgena 5           PL                 witold-bartnik
# 3      3      ul.Zjednoczenia 10           PL                marek-beniowski
# 4      4        ul. 3 Maja 13/15           PL                  szymon-bialka
#
#   company company_doc_id country currency  donations_grants  \
# 0  abbvie            NaN      PL      NaN               NaN
# 1  abbvie            NaN      PL      NaN               NaN
# 2  abbvie            NaN      PL      NaN               NaN
# 3  abbvie            NaN      PL      NaN               NaN
# 4  abbvie            NaN      PL      NaN               NaN
#
#    donations_grants_dirty  ...   sponsorship_dirty  title    total  \
# 0                     NaN  ...                 NaN    NaN   2600.0
# 1                     NaN  ...                 NaN    NaN   1849.0
# 2                     NaN  ...                 NaN    NaN   4030.0
# 3                     NaN  ...                 NaN    NaN  13272.0
# 4                     NaN  ...                 NaN    NaN    154.0
#
#    total_dirty travel_accommodation travel_accommodation_dirty type  uci  \
# 0       2600.0                  NaN                        NaN  hcp  NaN
# 1       1849.0                  NaN                        NaN  hcp  NaN
# 2       4030.0                  NaN                        NaN  hcp  NaN
# 3      13272.0               9517.0                     9517.0  hcp  NaN
# 4        154.0                154.0                      154.0  hcp  NaN
#
#     uid  year
# 0  None  2015
# 1  None  2015
# 2  None  2015
# 3  None  2015
# 4  None  2015
#
# [5 rows x 35 columns]

# %%
df.dtypes
# Out:
# index                           int64
# address                        object
# base_country                   object
# clean_name                     object
# company                        object
# company_doc_id                 object
# country                        object
# currency                       object
# donations_grants              float64
# donations_grants_dirty        float64
# fees                          float64
# fees_dirty                    float64
# first_name                     object
# gender                        float64
# last_name                      object
# location                       object
# name                           object
# origin                         object
# postcode                      float64
# recipient_detail               object
# registration_fees             float64
# registration_fees_dirty       float64
# related_expenses              float64
# related_expenses_dirty        float64
# sponsorship                   float64
# sponsorship_dirty             float64
# title                          object
# total                         float64
# total_dirty                   float64
# travel_accommodation          float64
# travel_accommodation_dirty    float64
# type                           object
# uci                            object
# uid                            object
# year                            int64
# dtype: object

# %% [markdown]
# ### Spot check addresses

# %%
utils.company_sample(df)[['company', 'title', 'name', 'address', 'location', 'postcode', 'country']]
# Out:
#     company title                                          name  \
# 178   bayer  None                                 Joanna Kubiak
# 277   bayer   NaN                                   Comarch S.A
# 309   bayer   NaN  Mazowiecki Szpital Specjalistyczny Sp. z o.o
# 108  abbvie   NaN           Polskie Towarzystwo Neonatologiczne
# 21   abbvie   NaN                               Maciej Gonciarz
# 116  abbvie   NaN               SP Wojewódzki Szpital Zespolony
#
#                          address   location  postcode country
# 178             ul.Ujejskiego 75  Bydgoszcz       NaN      PL
# 277  Ul. Aleja Jana Pawła Ii 39A     Kraków       NaN      PL
# 309        Ul. Aleksandrowicza 5      Radom       NaN      PL
# 108                  ul.Karowa 2   Warszawa       NaN      PL
# 21                  pl.Medyków 1  Sosnowiec       NaN      PL
# 116                ul.Arkońska 4   Szczecin       NaN      PL

# %% [markdown]
# ### Spot check names

# %%
cname = ['company', 'gender', 'title', 'clean_name', 'name', 'first_name', 'last_name', 'type']
utils.company_sample(df[df['type'] == 'hcp'])[cname]
# Out:
#     company  gender      title                  clean_name  \
# 37   abbvie     NaN        NaN  przemyslaw-laniewski-wollk
# 53   abbvie     NaN        NaN       malgorzata-przygodzka
# 69   abbvie     NaN        NaN    jadwiga-swikszcz-gniadek
# 192   bayer     NaN       None                  ewa-wywial
# 163   bayer     NaN  Prof. Dr.               konrad-rejdak
# 178   bayer     NaN       None               joanna-kubiak
#
#                            name  first_name         last_name type
# 37   Przemysław Łaniewski-Wołłk  Przemysław   Łaniewski-Wołłk  hcp
# 53        Małgorzata Przygodzka  Małgorzata        Przygodzka  hcp
# 69     Jadwiga Świkszcz-Gniadek     Jadwiga  Świkszcz-Gniadek  hcp
# 192                  Ewa Wywiał         Ewa            Wywiał  hcp
# 163               Konrad Rejdak      Konrad            Rejdak  hcp
# 178               Joanna Kubiak      Joanna            Kubiak  hcp

# %%
cname = ['company', 'recipient_detail', 'name']
utils.company_sample(df[df['type'] == 'hco'])[cname]
# Out:
#     company recipient_detail  \
# 251   bayer             None
# 245   bayer             None
# 307   bayer             None
# 90   abbvie             None
# 107  abbvie             None
# 93   abbvie             None
#
#                                                   name
# 251                      Wojewódzkie Centrum Szpitalne
# 245                       BCO Szpital Miejski-Poradnie
# 307  Powiatowy Szpital Specjalistyczny W Stalowej Woli
# 90        Fundacja Rozwoju Neonatologii w Wielkopolsce
# 107                   Polskie Towarzystwo Naukowe AIDS
# 93                          Fundacja Watch Health Care

# %%
df.to_csv('./data/combined_cleaned.csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Find Dirty Totals

# %%
dirty_total = checks.check_computed_total(df)
dirty_total.to_csv('data/dirty_totals.csv', index=False, encoding='utf-8')
dirty_total.head()
# Out:
# Empty DataFrame
# Columns: [company, index, name, address, total, total_dirty, computed_total, registration_fees, travel_accommodation, fees, donations_grants, sponsorship, related_expenses]
# Index: []

# %% [markdown]
# ### Find Duplicates

# %%
companies = list(df['company'].value_counts().index)
WINDOW_SIZE = round(len(companies) * 3)

compare_rows = dedupe.compare_rows

with get_linker(df, field='uid') as linker:

    print('Comparing sort by name')
    linker(sort_cols=['name', 'address', 'location'], window_size=WINDOW_SIZE, cmp=compare_rows)

    print('Comparing hcp sort by last name')
    linker(sort_cols=['last_name', 'address', 'location'], condition=(df['type'] == 'hcp'),
           window_size=WINDOW_SIZE, cmp=compare_rows)

    print('Comparing sort by address')
    linker(sort_cols=['address', 'location', 'name'],
       window_size=WINDOW_SIZE, cmp=compare_rows)

    print('Comparing sort by location,address')
    linker(sort_cols=['location', 'address', 'name'],
       window_size=WINDOW_SIZE, cmp=compare_rows)
# Out:
# [ 22 %] Time elapsed: 00:00:00 | ETA: 00:00:00
# Comparing sort by name
# [ 17 %] Time elapsed: 00:00:00 | ETA: 00:00:00
# Comparing hcp sort by last name
# [ 28 %] Time elapsed: 00:00:00 | ETA: 00:00:00
# Comparing sort by address
# [ 31 %] Time elapsed: 00:00:00 | ETA: 00:00:00
# Comparing sort by location,address
# [ 98 %] Time elapsed: 00:00:00 | ETA: 00:00:00

# %%
print(len(df), len(df.groupby('uid')))
# Out:
# 394 387

# %%
duplicates = df.groupby('uid').size() > 1
duplicates = duplicates[duplicates]
print('duplicates: ', len(duplicates))
df[df['uid'].isin(duplicates.index)].sort_values('uid')[['company', 'name', 'address', 'postcode', 'location', 'type']].head(50)
# Out:
# duplicates:  7
#     company                                               name  \
# 128  abbvie              Szpital Specjalistyczny im. J. Dietla
# 264   bayer   Szpital Specjalistyczny im. J. Dietla w Krakowie
# 130  abbvie                    Uniwersytecki Szpital Kliniczny
# 215   bayer      Uniwersytecki Szpital Kliniczny W Białymstoku
# 146  abbvie                   ZOZ Szpital w Suchej Beskidzkiej
# 322   bayer                   ZOZ Szpital w Suchej Beskidzkiej
# 106  abbvie                 Polskie Towarzystwo Kardiologiczne
# 341   bayer                 Polskie Towarzystwo Kardiologiczne
# 116  abbvie                    SP Wojewódzki Szpital Zespolony
# 320   bayer                    SP Wojewódzki Szpital Zespolony
# 36   abbvie                                    Piotr Landowski
# 155   bayer                                    Piotr Landowski
# 125  abbvie  Stowarzyszenie Przyjaciół Szpitala Wojewódzkie...
# 314   bayer  Stowarzyszenie Przyjaciol Szpitala Wojewodzkie...
#
#                             address  postcode         location type
# 128                   Ul.Skarbowa 4       NaN           Kraków  hco
# 264                  Ul. Skarbowa 4       NaN           Kraków  hco
# 130       Ul.Skłodowskiej-Curie 24A       NaN        Białystok  hco
# 215  UL. M. SKŁODOWSKIEJ-CURIE 24 a       NaN        Białystok  hco
# 146                 Ul.Szpitalna 22       NaN  Sucha Beskidzka  hco
# 322                 ul.Szpitalna 22       NaN  Sucha Beskidzka  hco
# 106                ul.Stawki 3A/1-2       NaN         Warszawa  hco
# 341          Ul. Stawki 3A Lok. 1-2       NaN         Warszawa  hco
# 116                   ul.Arkońska 4       NaN         Szczecin  hco
# 320                   ul.Arkońska 4       NaN         Szczecin  hco
# 36               ul.Nowe Ogrody 1-6       NaN           Gdańsk  hcp
# 155                 Nowe Ogrody 1-6       NaN           Gdańsk  hcp
# 125                   ul.Lwowska 60       NaN          Rzeszów  hco
# 314                  Ul. Lwowska 60       NaN          Rzeszow  hco

# %% [markdown]
# ### Run Geocoding

# %%
df = df.progress_apply(functools.partial(geocode.run_geocoding, country=DEFAULT_COUNTRY.lower()), 1)
# Out:
# [100 %] Time elapsed: 00:00:02 | ETA: 00:00:00
# Total time elapsed: 00:00:02

# %%
df['postcode'] = df.progress_apply(geocode.get_postcode, 1)
# Out:
# [ 99 %] Time elapsed: 00:00:01 | ETA: 00:00:00

# %%
df['uid_original'] = df['uid'].copy()
print('Comparing sort by lat,lng')

compare_rows = functools.partial(dedupe.compare_geocoded_rows)
run_linker(df, sort_cols=['lat', 'lng', 'name'], window_size=WINDOW_SIZE, cmp=compare_rows)
# Out:
# [ 27 %] Time elapsed: 00:00:00 | ETA: 00:00:00
# Comparing sort by lat,lng
# [ 98 %] Time elapsed: 00:00:00 | ETA: 00:00:00

# %%
df[df['uid'] != df['uid_original']][['name', 'address', 'lat', 'lng', 'location', 'uid', 'uid_original', 'company']]
# Out:
#                                         name            address        lat  \
# 268  Sp Zoz Szpital Uniwersytecki W Krakowie  Ul.  Kopernika 36  50.063024
#
#            lng location                                   uid  \
# 268  19.951229   Kraków  506ebd61-6e6c-4750-91cc-384667bb2d13
#
#                              uid_original company
# 268  d34ec775-189e-44f3-afff-3948fc52783d   bayer

# %%
duplicates = df.groupby('uid').size() > 1
duplicates = duplicates[duplicates]
print('duplicates: ', len(duplicates))
df[df['uid'].isin(duplicates.index)].sort_values('uid')[['company', 'name', 'address', 'postcode', 'location', 'uid', 'uid_original']].head(50)
# Out:
# duplicates:  8
#     company                                               name  \
# 128  abbvie              Szpital Specjalistyczny im. J. Dietla
# 264   bayer   Szpital Specjalistyczny im. J. Dietla w Krakowie
# 118  abbvie                       SP ZOZ Szpital Uniwersytecki
# 268   bayer            Sp Zoz Szpital Uniwersytecki W Krakowie
# 130  abbvie                    Uniwersytecki Szpital Kliniczny
# 215   bayer      Uniwersytecki Szpital Kliniczny W Białymstoku
# 146  abbvie                   ZOZ Szpital w Suchej Beskidzkiej
# 322   bayer                   ZOZ Szpital w Suchej Beskidzkiej
# 106  abbvie                 Polskie Towarzystwo Kardiologiczne
# 341   bayer                 Polskie Towarzystwo Kardiologiczne
# 116  abbvie                    SP Wojewódzki Szpital Zespolony
# 320   bayer                    SP Wojewódzki Szpital Zespolony
# 36   abbvie                                    Piotr Landowski
# 155   bayer                                    Piotr Landowski
# 125  abbvie  Stowarzyszenie Przyjaciół Szpitala Wojewódzkie...
# 314   bayer  Stowarzyszenie Przyjaciol Szpitala Wojewodzkie...
#
#                             address postcode         location  \
# 128                   Ul.Skarbowa 4   33-332           Kraków
# 264                  Ul. Skarbowa 4   33-332           Kraków
# 118                 ul.Kopernika 36     None           Kraków
# 268               Ul.  Kopernika 36     None           Kraków
# 130       Ul.Skłodowskiej-Curie 24A     None        Białystok
# 215  UL. M. SKŁODOWSKIEJ-CURIE 24 a     None        Białystok
# 146                 Ul.Szpitalna 22   34-200  Sucha Beskidzka
# 322                 ul.Szpitalna 22   34-200  Sucha Beskidzka
# 106                ul.Stawki 3A/1-2     None         Warszawa
# 341          Ul. Stawki 3A Lok. 1-2     None         Warszawa
# 116                   ul.Arkońska 4     None         Szczecin
# 320                   ul.Arkońska 4     None         Szczecin
# 36               ul.Nowe Ogrody 1-6     None           Gdańsk
# 155                 Nowe Ogrody 1-6     None           Gdańsk
# 125                   ul.Lwowska 60     None          Rzeszów
# 314                  Ul. Lwowska 60     None          Rzeszow
#
#                                       uid  \
# 128  170d7600-7066-4430-8930-302e4f2a974d
# 264  170d7600-7066-4430-8930-302e4f2a974d
# 118  506ebd61-6e6c-4750-91cc-384667bb2d13
# 268  506ebd61-6e6c-4750-91cc-384667bb2d13
# 130  51b6be13-f941-4e0b-b8f3-6f84e8599c29
# 215  51b6be13-f941-4e0b-b8f3-6f84e8599c29
# 146  908e72ab-c72d-49b4-a17f-975a1a609b99
# 322  908e72ab-c72d-49b4-a17f-975a1a609b99
# 106  920db4f3-f61e-4ffb-af00-e16df18e1fe1
# 341  920db4f3-f61e-4ffb-af00-e16df18e1fe1
# 116  927de03c-d0af-451b-abfa-942ffe923358
# 320  927de03c-d0af-451b-abfa-942ffe923358
# 36   a76902b8-6af5-4175-9e6f-32f6ba4ade15
# 155  a76902b8-6af5-4175-9e6f-32f6ba4ade15
# 125  decc5d25-08cc-4128-8408-141326e3a6f1
# 314  decc5d25-08cc-4128-8408-141326e3a6f1
#
#                              uid_original
# 128  170d7600-7066-4430-8930-302e4f2a974d
# 264  170d7600-7066-4430-8930-302e4f2a974d
# 118  506ebd61-6e6c-4750-91cc-384667bb2d13
# 268  d34ec775-189e-44f3-afff-3948fc52783d
# 130  51b6be13-f941-4e0b-b8f3-6f84e8599c29
# 215  51b6be13-f941-4e0b-b8f3-6f84e8599c29
# 146  908e72ab-c72d-49b4-a17f-975a1a609b99
# 322  908e72ab-c72d-49b4-a17f-975a1a609b99
# 106  920db4f3-f61e-4ffb-af00-e16df18e1fe1
# 341  920db4f3-f61e-4ffb-af00-e16df18e1fe1
# 116  927de03c-d0af-451b-abfa-942ffe923358
# 320  927de03c-d0af-451b-abfa-942ffe923358
# 36   a76902b8-6af5-4175-9e6f-32f6ba4ade15
# 155  a76902b8-6af5-4175-9e6f-32f6ba4ade15
# 125  decc5d25-08cc-4128-8408-141326e3a6f1
# 314  decc5d25-08cc-4128-8408-141326e3a6f1

# %%
df.to_csv('data/geocoded.csv', encoding='utf-8', index=False)

# %%
final_df = export.make_entities_df(df)
final_df.head()
# Out:
# [100 %] Time elapsed: 00:00:10 | ETA: 00:00:00
# Total time elapsed: 00:00:10
#                    address base_country               clean_name  \
# 0    Ul. Prosta 2/14 Lok 5           PL                     None
# 1             Ul.Dojazd 34           PL  barbara-sobczak-moryson
# 2  Strzelców Bytomskich 11           PL                     None
# 3       Ul.Traugutta 112 E           PL                     None
# 4             ul.Długa 1/2           PL              tomasz-losy
#
#      company_doc_id computed_total country donations_grants_dirty fees_dirty  \
# 0  BAYER-2015-61549          14000      PL                  14000       None
# 1  BAYER-2015-61696           4298      PL                   None       None
# 2  BAYER-2015-61589            600      PL                    600       None
# 3              None          15598      PL                  15598       None
# 4              None           2000      PL                   None       2000
#
#   first_name gender                  ...                   \
# 0       None   None                  ...
# 1    Barbara   None                  ...
# 2       None   None                  ...
# 3       None   None                  ...
# 4     Tomasz   None                  ...
#
#   registration_fees_dirty related_expenses_dirty sponsorship_dirty title  \
# 0                    None                   None              None  None
# 1                    1802                   None              None  None
# 2                    None                   None              None  None
# 3                    None                   None              None  None
# 4                    None                   None              None  None
#
#    total total_dirty travel_accommodation_dirty type   uci  \
# 0   None        None                       None  hco
# 1   None        None                       2496  hcp
# 2   None        None                       None  hco
# 3  15598       15598                       None  hco  None
# 4   2000        2000                       None  hcp  None
#
#                            uid_original
# 0  005f8e35-0e26-4078-85b6-236e4a399588
# 1  022a0287-1d01-4c93-ad4b-d86f391b84da
# 2  024f0148-814a-4d82-820e-bc11afb3b4b1
# 3  02bb48f1-b8d5-42b1-bf31-da45b88319c7
# 4  03ff4073-6e55-4368-a6c4-7d7f28645d96
#
# [5 rows x 29 columns]

# %%
final_df = export.make_slugs(final_df)
final_df.head()
# Out:
#                    address base_country               clean_name  \
# 0    Ul. Prosta 2/14 Lok 5           PL                     None
# 1             Ul.Dojazd 34           PL  barbara-sobczak-moryson
# 2  Strzelców Bytomskich 11           PL                     None
# 3       Ul.Traugutta 112 E           PL                     None
# 4             ul.Długa 1/2           PL              tomasz-losy
#
#      company_doc_id computed_total country donations_grants_dirty fees_dirty  \
# 0  BAYER-2015-61549          14000      PL                  14000       None
# 1  BAYER-2015-61696           4298      PL                   None       None
# 2  BAYER-2015-61589            600      PL                    600       None
# 3              None          15598      PL                  15598       None
# 4              None           2000      PL                   None       2000
#
#   first_name gender                        ...                          \
# 0       None   None                        ...
# 1    Barbara   None                        ...
# 2       None   None                        ...
# 3       None   None                        ...
# 4     Tomasz   None                        ...
#
#   sponsorship_dirty title  total total_dirty travel_accommodation_dirty type  \
# 0              None  None   None        None                       None  hco
# 1              None  None   None        None                       2496  hcp
# 2              None  None   None        None                       None  hco
# 3              None  None  15598       15598                       None  hco
# 4              None  None   2000        2000                       None  hcp
#
#     uci                          uid_original  \
# 0        005f8e35-0e26-4078-85b6-236e4a399588
# 1        022a0287-1d01-4c93-ad4b-d86f391b84da
# 2        024f0148-814a-4d82-820e-bc11afb3b4b1
# 3  None  02bb48f1-b8d5-42b1-bf31-da45b88319c7
# 4  None  03ff4073-6e55-4368-a6c4-7d7f28645d96
#
#                                             slug_raw  \
# 0  Fundacja-Walki-Ze-Slepota-I-Rehabilitacji-Slab...
# 1                  Barbara-Sobczak-Moryson-Poznan-pl
# 2  Polskie-Towarzystwo-Lekarskie-Zarzad-O-W-Katow...
# 3        Fundacja-Rozwoju-Ochrony-Zdrowia-Wroclaw-pl
# 4                              Tomasz-Losy-Poznan-pl
#
#                                                 slug
# 0  Fundacja-Walki-Ze-Slepota-I-Rehabilitacji-Slab...
# 1                  Barbara-Sobczak-Moryson-Poznan-pl
# 2  Polskie-Towarzystwo-Lekarskie-Zarzad-O-W-Katow...
# 3        Fundacja-Rozwoju-Ochrony-Zdrowia-Wroclaw-pl
# 4                              Tomasz-Losy-Poznan-pl
#
# [5 rows x 31 columns]

# %%
final_df.columns
# Out:
# Index(['address', 'base_country', 'clean_name', 'company_doc_id',
#        'computed_total', 'country', 'donations_grants_dirty', 'fees_dirty',
#        'first_name', 'gender', 'index', 'last_name', 'lat', 'lng', 'location',
#        'name', 'origin', 'payments', 'postcode', 'registration_fees_dirty',
#        'related_expenses_dirty', 'sponsorship_dirty', 'title', 'total',
#        'total_dirty', 'travel_accommodation_dirty', 'type', 'uci',
#        'uid_original', 'slug_raw', 'slug'],
#       dtype='object')

# %%
final_df.to_csv('data/pl_final_geocoded.csv', index=False, encoding='utf-8')
